# %% [markdown]
# <a href="https://colab.research.google.com/github/Amasha03/Speech-to-Text/blob/main/WhisperLargeV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Speech to Text with Whisper Large V3

# %%
# Install the official Whisper library from GitHub
# !pip install git+https://github.com/openai/whisper.git

# Ensure ffmpeg is installed and updated on the system
# !sudo apt update && sudo apt install ffmpeg -y
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-tdfycfmd
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-tdfycfmd
#   Resolved https://github.com/openai/whisper.git to commit 04f449b8a437f1bbd3dba5c9f826aca972e7709a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=b7c756f17be386018f3cb2c4486a555484a8efc33ae7bdb4b8ce441a3476f4de
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r6gypj7s/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# ...

# %% [markdown]
# ##Sinhala Language

# %%
# !whisper "omnivoice-audio-1781154173519.mp3" --model large-v3 --device cuda
# Out:
#  72%|███████████████████████████▏          | 2.06G/2.88G [00:15<00:05, 147MiB/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/whisper", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/whisper/transcribe.py", line 595, in cli
#     model = load_model(model_name, device=device, download_root=model_dir)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/whisper/__init__.py", line 137, in load_model
#     checkpoint_file = _download(_MODELS[name], download_root, in_memory)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/whisper/__init__.py", line 86, in _download
#     output.write(buffer)
# KeyboardInterrupt
# ^C

# %%
import whisper
import torch

# 1. Clear any cached memory just in case
torch.cuda.empty_cache()

# 2. Load the model specifying FP16 precision
# whisper.load_model automatically uses float16 if cuda is selected,
# but we can ensure everything plays nice by clearing the cache first.
model = whisper.load_model("large-v3", device="cuda")

# 3. Force Sinhala transcription
result = model.transcribe("omnivoice-audio-1781154173519.mp3", language="si", fp16=True)

print(result["text"])
# Out:
#  මිනිරින් කරන්න කරන්න.

# %%
# !pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.2 MB/s eta 0:00:00
# ...

# %%
from jiwer import wer, cer

# 1. Provide your Ground Truth (Manually verified Sinhala)
reference = "මම අයිස්ක්‍රීම් කන්න කැමතියි."

# 2. Provide the WhisperX output text
hypothesis = "මිනිරින් කරන්න කරන්න."

# Calculate Word Error Rate (WER)
error_rate = wer(reference, hypothesis)
accuracy = (1 - error_rate) * 100

# Calculate Character Error Rate (CER) - highly recommended for Sinhala script
char_error_rate = cer(reference, hypothesis)
char_accuracy = (1 - char_error_rate) * 100

print("--- Accuracy Metrics ---")
print(f"Word Error Rate (WER): {error_rate:.2%}")
print(f"Word Accuracy: {accuracy:.2f}%\n")

print(f"Character Error Rate (CER): {char_error_rate:.2%}")
print(f"Character Accuracy (Phonetic Precision): {char_accuracy:.2f}%")
# Out:
# --- Accuracy Metrics ---
# Word Error Rate (WER): 100.00%
# Word Accuracy: 0.00%
#
# Character Error Rate (CER): 62.07%
# Character Accuracy (Phonetic Precision): 37.93%

# %% [markdown]
# ##Tamil Language

# %%
# !whisper "tamRefAudio1.wav" --model large-v3 --device cuda
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Tamil
# [00:00.000 --> 00:03.000]  நான் இன்று என் கைபேசியைக் கொண்டு வர மறந்து விட்டேன்

# %%
from jiwer import wer, cer

# 1. Provide your Ground Truth (Manually verified Sinhala)
reference = "நான் இன்று என் கைபேசியைக் கொண்டுவர மறந்துவிட்டேன்"

# 2. Provide the WhisperX output text
hypothesis = "நான் இன்று என் கைபேசியைக் கொண்டு வர மறந்து விட்டேன்"

# Calculate Word Error Rate (WER)
error_rate = wer(reference, hypothesis)
accuracy = (1 - error_rate) * 100

# Calculate Character Error Rate (CER) - highly recommended for Sinhala script
char_error_rate = cer(reference, hypothesis)
char_accuracy = (1 - char_error_rate) * 100

print("--- Accuracy Metrics ---")
print(f"Word Error Rate (WER): {error_rate:.2%}")
print(f"Word Accuracy: {accuracy:.2f}%\n")

print(f"Character Error Rate (CER): {char_error_rate:.2%}")
print(f"Character Accuracy (Phonetic Precision): {char_accuracy:.2f}%")
# Out:
# --- Accuracy Metrics ---
# Word Error Rate (WER): 66.67%
# Word Accuracy: 33.33%
#
# Character Error Rate (CER): 4.08%
# Character Accuracy (Phonetic Precision): 95.92%
